# %%
import startJVM
import jpype
import jpype.imports
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /Users/hangal1/Documents/research/rda/radsim/proj-radsim/src

# %%
from gov.llnl.rtk.physics import Nuclides
from gov.llnl.rtk.physics import SourceImpl
from gov.llnl.rtk.physics import EmissionCalculator
from gov.llnl.ensdf.decay import BNLDecayLibrary
from gov.llnl.rtk.physics import ActivityUnit

# %%
from java.nio.file import Paths
from gov.llnl.ensdf import EnsdfParser
from gov.llnl.ensdf.decay import SplitIsomers
from gov.llnl.ensdf.decay import SandiaFormatter
from gov.nist.xray import NISTLibrary

# %%
### beginning of demo section
# This is to test the calculate function with a chosen decay library
Bq = ActivityUnit.Bq
Cs137 = SourceImpl.fromActivity(Nuclides.get("Cs137"), 100, Bq)
Ba137m = SourceImpl.fromActivity(Nuclides.get("Ba137m"), 94.7, Bq)
Co60 = SourceImpl.fromActivity(Nuclides.get("Co60"), 100, Bq)
Na22 = SourceImpl.fromActivity(Nuclides.get("Na22"), 100, Bq)
Ir192 = SourceImpl.fromActivity(Nuclides.get("Ir192"), 100, Bq)
Mo99 = SourceImpl.fromActivity(Nuclides.get("Ir192"), 100, Bq)

# %%
bnllib = BNLDecayLibrary()
bnllib.loadFile(Paths.get("BNL2023.txt"))
emcal = EmissionCalculator()
emcal.setDecayLibrary(bnllib)

from java.util import ArrayList
sourceList = ArrayList()
sourceList.add(Cs137)
sourceList.add(Ba137m)
# sourceList.add(Co60)
# sourceList.add(Na22)
# sourceList.add(Ir192)
# sourceList.add(Mo99)

beta_record = {'E':[], 'I': []}
gamma_record = {'E':[], 'I': []}
xray_record = {'E':[], 'I': []}

out = emcal.calculate(sourceList)

for emission in out.getBetas():
    e_e = emission.getEnergy().getValue()
    e_i = emission.getIntensity().getValue()
    beta_record['E'].append(e_e)
    beta_record['I'].append(e_i)
    print("Beta-: ", e_e, e_i, emission.getForbiddenness())

for emission in out.getGammas():
    e_e = emission.getEnergy().getValue()
    e_i = emission.getIntensity().getValue()
    gamma_record['E'].append(e_e)
    gamma_record['I'].append(e_i)
    print("Gamma: ", e_e, e_i)

for emission in out.getXrays():
    e_e = emission.getEnergy().getValue()
    e_i = emission.getIntensity().getValue()
    xray_record['E'].append(e_e)
    xray_record['I'].append(e_i)
    print("Xray: ", e_e, e_i,emission.getName())
# Out:
# Missing nuclide 30AR 0.7E3
# Missing nuclide 39SC 0
# Bad quantity 0+X
# Missing nuclide 50K 172.0
# Missing nuclide 58NI 16795
# Bad quantity 0+X
# Bad quantity 0+X
# Bad quantity 0+X
# Bad quantity 202.1+X
# Bad quantity 0+Y
# Missing nuclide 60MN 114
# Bad quantity 0+X
# Bad quantity 0+Y
# Missing nuclide 64MN 175.5
# Missing nuclide 67CU 3463.6
# Bad quantity X
# Bad quantity 0+X
# Bad quantity 0+X
# Bad quantity 0+Y
# Bad quantity 0+X
# Bad quantity 0+Y
# Bad quantity 0+X
# Missing nuclide 76NI 2420
# Missing nuclide 78GA 560.0
# Bad quantity 0+X
# Missing nuclide 81GE 679.14
# Missing nuclide 82SE 3518.6
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Missing nuclide 84NB 338.7
# Bad quantity 69+Y
# Bad quantity 69+Y
# Missing nuclide 88BR 270.1
# Bad quantity 0.0+X
# Bad quantity X
# Bad quantity Y
# Bad quantity 0+X
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 0+X
# Bad quantity 0+Y
# Missing nuclide 94AG 660
# Missing nuclide 94Y 1202.3
# Bad quantity X+0.0
# Missing nuclide 95KR 195.5
# Missing nuclide 95RH 2236
# Bad quantity 0.0+Y
# Bad quantity Y
# Missing nuclide 96RB 1134.6
# Bad quantity 0.0+X
# Bad quantity 0.0+Y
# Missing nuclide 98Y 410
# Missing nuclide 99Y 2141.70
# Bad quantity 0.0+X
# Bad quantity 0.0+Y
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Missing nuclide 104NB 2.2E+2
# Bad quantity 0.0+X
# Bad quantity 0.0+Y
# Bad quantity Y
# Bad quantity 0+X
# Bad quantity 0+Y
# Missing nuclide 115SB 1300.21
# Missing nuclide 115I 413
# Bad quantity 0.0+X
# Bad quantity 138.5+X
# Bad quantity 104.0+X
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Missing nuclide 120AG 203.0
# Missing nuclide 120AG 203
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Missing nuclide 121PD 135
# Bad quantity 2721.5+X
# Bad quantity X
# Bad quantity 0+X
# Bad quantity 1426.1+Y
# Missing nuclide 123SB 2613.7
# Bad history record 123TE 2H $by running log| {Ift}
# Missing nuclide 123CS 156.30
# Bad quantity 62.2+X
# Bad quantity 231.1+X
# Bad quantity 0.0+X
# Missing nuclide 124SN 2656.6
# Bad quantity 0.0+X
# Bad quantity 0.0+Y
# Bad quantity 0+X
# Bad quantity 859.9+X
# Bad quantity X
# Bad quantity 1969+X
# Bad quantity 254.8+X
# Bad quantity 0+X
# Bad quantity 0+Y
# Missing nuclide 126IN 243.3
# Bad quantity 0.0+V
# Bad quantity 0.0+W
# Unrecognized part "|a(K)exp=0.36 {I6} for an unresolved transition"
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 0+X
# Missing nuclide 129IN 1687.97
# Missing nuclide 129SB 2139.4
# Bad quantity 0+X
# Bad quantity 0+Z
# Missing nuclide 130CD 2130
# Missing nuclide 130IN 388.8
# Missing nuclide 131IN 363
# Missing nuclide 131IN 302
# Bad quantity 0.0+X
# Missing nuclide 131CE 161.98
# Bad quantity 0+X
# Bad quantity 0+X
# Missing nuclide 133PM 129.7
# Bad quantity 0+Y
# Bad quantity 0.0+X
# Bad quantity 336.44+X
# Bad quantity 0.0+X
# Bad quantity 0.0+Y
# Missing nuclide 134ND 2293.0
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 68.7+Y
# Bad quantity X
# Bad quantity Y
# Missing nuclide 136CE 3095.0
# Bad quantity X
# Bad quantity Y
# Missing nuclide 138PR 364
# Bad quantity X
# Bad quantity 0+X
# Bad quantity 298.2+X
# Bad quantity 0.0+X
# Bad quantity 0+X
# Missing nuclide 142PR 911.4
# Bad quantity 0.0+X
# Missing nuclide 142TB 652.1
# Bad quantity Y
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 779.57+X
# Bad quantity 0.0+X
# Bad quantity 0+X
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 694.4+X
# Bad quantity 0+X
# Missing nuclide 149ER 741.69
# Bad quantity 0+X
# Bad quantity 0+Y
# Missing nuclide 149ER 741.69
# Missing nuclide 150LU 22
# Bad quantity 0+X
# Bad quantity X
# Bad quantity 0.0+X
# Bad quantity 0+X
# Bad quantity 0+X
# Missing nuclide 151TM 6908.5
# Bad quantity 0.0+X
# Bad quantity 2448+Z
# Bad quantity 150+X
# Bad quantity X
# Bad quantity 0+X
# Bad quantity 2554.9+X
# Bad quantity 0+X
# Missing nuclide 156HF 1959
# Bad quantity X
# Bad quantity 2578.2+X
# Bad quantity 0+X
# Bad quantity 0+X
# Bad quantity 0+Y
# Bad quantity 0+X
# Bad quantity 0+Y
# Bad quantity 0+X
# Bad quantity 130.4+Y
# Bad quantity 2671+X
# Bad quantity 0+X
# Missing nuclide 159TA 64
# Bad quantity 0+Y
# Bad production norm record 156PM PN                       1.0                                           5
# Missing nuclide 156PM 150.3
# Bad production norm record 156PM PN                       0.03092 8                                     5
# Missing nuclide 156PM 150.3
# Bad quantity 49.630+X
# Bad quantity 52.4+X
# Bad quantity 52.37+X
# Bad quantity X
# Bad quantity Y
# Bad quantity 121+X
# Bad quantity 260+X
# Bad quantity 0+X
# Bad quantity 0.0+X
# Missing nuclide 159GD 67.829
# Bad quantity 169.56+X
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 166.5+X
# Missing nuclide 165RE 48
# Missing nuclide 165IR 180
# Bad quantity X
# Handle continuation 162YB2   +1.9 M)
# Bad quantity X
# Bad quantity Y
# Bad quantity 0+X
# Bad quantity 0+X
# Bad quantity 0+X
# Bad quantity 0+X
# Missing nuclide 165RE 48
# Missing nuclide 166HO 5.969
# Bad quantity 0.0+X
# Bad quantity 0+X
# Bad quantity 0.0+X
# Missing nuclide 173AU 214
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 0.0+Y
# Missing nuclide 172IR 139
# Bad quantity 0+X
# Bad quantity 0+Y
# Missing nuclide 177AU 189
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 0.0+Y
# Missing nuclide 182TL 100
# Bad quantity 0.0+X
# Bad quantity 0.0+Y
# Missing nuclide 181TA 615
# Bad quantity 0.0+X
# Bad quantity 0+X
# Bad quantity 0+X
# Bad quantity 0+X
# Missing nuclide 183HF 1464
# Bad quantity 4180.2+X
# Missing nuclide 184OS 2366.81
# Bad quantity 0.0+X
# Bad quantity 0.0+Y
# Bad quantity 0+X
# Missing nuclide 185W 197.43
# Bad quantity 0.0+X
# Missing nuclide 186TA 347.9
# Bad quantity 0.0+X
# Bad quantity X+0.0
# Bad quantity 0.0+X
# Bad quantity 0+X
# Bad quantity 0+X
# Bad quantity 0.0+X
# Missing nuclide 189PB 2475.53
# Missing nuclide 193AT 39
# Bad quantity 0.0+X
# Bad quantity 0+X
# Bad quantity 0+Y
# Bad quantity 0.0+X
# Missing nuclide 195RN 59
# Bad quantity 160.1+X
# Missing nuclide 192RE 267
# Bad quantity 0.0+X
# Bad quantity 365.2+X
# Bad quantity 365.0+X
# Bad quantity 0.0+X
# Missing nuclide 197RN 199
# Bad quantity 190.0+X
# Bad quantity 0+X
# Bad quantity 0+Y
# Missing nuclide 199AT 240
# Missing nuclide 199FR 47
# Missing nuclide 200AT 335
# Bad quantity 0+X
# Bad quantity 248.5+X
# Bad quantity Y
# Bad quantity 391.7+X
# Bad quantity 102+X
# Bad quantity 424.1+X
# Bad quantity 1922.3+X
# Bad quantity 0+X
# Missing nuclide 203RA 220
# Bad quantity 0+X
# Missing nuclide 204FR 47
# Missing nuclide 204FR 316
# Missing nuclide 201TL 919.47
# Missing nuclide 205RA 263
# Missing nuclide 202PT 1788.5
# Bad quantity 0+X
# Bad quantity 0+X
# Bad quantity 531+X
# Bad quantity 0.0+X
# Missing nuclide 207RA 558
# Missing nuclide 208AC 506
# Missing nuclide 209TH 436
# Bad quantity 0+X
# Missing nuclide 212PO 1476.4
# Missing nuclide 208RA 2147.4
# Bad quantity X+1366
# Missing nuclide 214RN 1442.7
# Missing nuclide 214RN 1625.1
# Missing nuclide 215FR 835.5
# Missing nuclide 215FR 1121.5
# Missing nuclide 215FR 1440.0
# Missing nuclide 215FR 1573.1
# Missing nuclide 211RA 1198.1
# Missing nuclide 216AT 57.11
# Missing nuclide 216AT 400
# Missing nuclide 216FR 133.3
# Missing nuclide 216U 2240
# Missing nuclide 217AC 1149.1
# Missing nuclide 217AC 1498.1
# Missing nuclide 218PA 83
# Missing nuclide 218U 2105
# Bad quantity 1347.50+X
# Bad quantity 1347.5+X
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 2251.91+X
# Bad quantity 0+X
# Missing nuclide 229TH 0.0076
# Bad quantity 73.92+X
# Bad quantity 73.92+X
# Bad quantity X
# Bad quantity 0+X
# Bad quantity 0+X
# Missing nuclide 245MD 300
# Bad quantity 0.0+X
# Bad quantity 0+X
# Bad quantity 0+Y
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 0+X
# Bad quantity 0+X
# Bad quantity 0+Y
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 0.0+X
# Bad quantity 0.0+Y
# Bad quantity 0.0+X
# Unrecognized part "CONF=|p3/2-[521] (1978Lo13)"
# Unrecognized part "CONF=|p7/2+[633] (1978Lo13)"
# Unrecognized part "CONF=|p5/2+[642] (1978Lo13)"
# Unrecognized part "CONF=|p1/2+[400] (1978Lo13)"
# Unrecognized part "CONF=|p1/2-[530] (1978Lo13)"
# Unrecognized part "CONF=|p1/2-[521] (1978Lo13)"
# Unrecognized part "CONF=|n1/2+[620] (1984Li05)"
# Unrecognized part "CONF=|n3/2+[622] (1984Li05)"
# Unrecognized part "CONF=|n1/2+[620] (1970Ah01)"
# Unrecognized part "CEL1+CEL2=0.13 AP (2005Ah09)"
# Unrecognized part "CEM=0.06 AP (2005Ah09)"
# Unrecognized part "CONF=|n3/2+[622] (1970Ah01)"
# Unrecognized part "CEL2=0.25 AP (2005Ah09)"
# Unrecognized part "CEL3=0.20 AP (2005Ah09)"
# Unrecognized part "CEM=0.20 AP (2005Ah09)"
# Unrecognized part "CEN=0.06 AP (2005Ah09)"
# Unrecognized part "CONF=|n1/2+[620] (2005Ah09)"
# Unrecognized part "CONF=|n7/2+[613] (2005Ah09)"
# Unrecognized part "BE2W=0.029 LT"
# Unrecognized part "BM1W=2.0E-5 GT"
# Unrecognized part "CONF=|n3/2+[622] (2005Ah09)"
# Unrecognized part "CONF=|n11/2-[725] (2005Ah09)"
# Unrecognized part "CONF=|n9/2-[734] (2005Ah09)"
# Unrecognized part "CONF=|n5/2+[622] (2005Ah09)"
# Unrecognized part "CONF=|n1/2-[750] (2005Ah09)"
# Unrecognized part "CONF=|[|n7/2+[613]~#1{+-}|]5/2-"
# Unrecognized part "CONF=|[|n7/2+[613]~#2{+-}|]3/2- (2000Ah09)"
# Unrecognized part "CONF=|[|n7/2+[613]~#1{+-}|]9/2- (2005Ah09)"
# Unrecognized part "CONF=|[|n7/2+[613]~#0{++}|]7/2+ (2005Ah09)"
# Unrecognized part "CONF=|p3/2-[521]"
# Unrecognized part "CONF=|p7/2+[633]"
# Unrecognized part "CONF=|p7/2-[514]"
# Unrecognized part "CEL1+CEL2=0.003 AP"
# Unrecognized part "EL1C+EL2C=0.1 AP"
# Unrecognized part "CEL3=0.002 LT"
# Unrecognized part "CEM=0.005 AP"
# Unrecognized part "EL3C=0.002 LT"
# Unrecognized part "EMC=0.005 AP"
# Unrecognized part "CEL3=0.003 LT"
# Unrecognized part "EL3C=0.002 LT"
# Unrecognized part "CONF=|p9/2+[624]"
# Unrecognized part "CEK=0.0014 AP"
# Unrecognized part "EKC=0.08 AP"
# Unrecognized part "CONF=|[|p7/2+[633]~#2{++}|]11/2+"
# Unrecognized part "CEK=0.009 AP"
# Unrecognized part "EKC=0.06 AP"
# Unrecognized part "CEK=0.2 AP"
# Unrecognized part "EKC=0.01 AP"
# Unrecognized part "CONF=|[|n9/2-[734]~#|n1/2+[620]~#|p3/2-[521]|]11/2+"
# Unrecognized part "CEL3=0.002 LT"
# Unrecognized part "EL3C=0.003 LT"
# Unrecognized part "CONF=|p3/2-[521]"
# Unrecognized part "CONF=|p7/2+[633]"
# Unrecognized part "CONF=|p7/2-[514]"
# Unrecognized part "CONF=|n9/2-[734] (2011As03)"
# Unrecognized part "CONF=|n5/2+[622] (2011As03)"
# Unrecognized part "CONF=|n7/2+[624] (2011As03)"
# Unrecognized part "CONF=|n1/2+[631] (2011As03)"
# Unrecognized part "CONF=|n1/2+[620] (2011As03)"
# Unrecognized part "ECC=5.5 GT (2011As03)"
# Unrecognized part "EKC=7 GT (2006He20)"
# Missing nuclide 251MD 844
# Unrecognized part "%IT=100 AP"
# Unrecognized part "CONF=|p7/2-[514]"
# Unrecognized part "CONF=|p1/2-[521]"
# Unrecognized part "CONF=|p7/2-[514]"
# Bad quantity 0+Z
# Bad quantity 1440+X
# Missing nuclide 257RF 75
# Bad quantity 0+X
# Bad quantity 0+X
# Bad quantity 1408.6+Y
# Bad quantity 0.0+X
# Bad quantity 0+Y
# Missing nuclide 257RF 75
# Bad quantity 0+X
# Bad quantity 0+X
# Bad quantity 0+X
# Missing nuclide 262BH 210
# Bad quantity X
# Bad quantity 152+X
# Missing nuclide 265HS 300
# Missing nuclide 26710 0.0
# Missing nuclide 26910 0.0
# Missing nuclide 270DS 1.13E3
# Unrecognized part "XREF=ABDFM"
# WARNING record missing NB specification
# WARNING level with no output 9670
# WARNING Unbalanced level 9670:TimeQuantity(1 MEV,AP) in=0.009000000000000001 out=0.0 2.0
# WARNING level with no output 3080
# WARNING Unbalanced level 3080:TimeQuantity(1 MEV,AP) in=0.16 out=0.0 2.0
# WARNING level with no output 5150
# WARNING Unbalanced level 5150:TimeQuantity(650 KEV,AP) in=0.16 out=0.0 2.0
# WARNING Decay to multiple daughters
# WARNING Decay to multiple daughters
# WARNING Beta without NB specified
# WARNING level with no output 11810
# WARNING Unbalanced level 11810:TimeQuantity(400 KEV,30) in=0.027000000000000003 out=0.0 2.0
# WARNING level with no output 2.78E+3
# WARNING Unbalanced level 2.78E+3:TimeQuantity(1.10 MEV,12) in=0.158 out=0.0 2.0
# WARNING level with no output 7940
# WARNING Unbalanced level 7940:TimeQuantity(1 MEV,AP) in=0.015 out=0.0 2.0
# WARNING level with no output 11282
# WARNING Unbalanced level 11282:TimeQuantity(575 KEV,50) in=0.011000000000000001 out=0.0 2.0
# WARNING level with no output 2429.4
# WARNING Unbalanced level 2429.4:TimeQuantity(0.78 KEV,13) in=0.297 out=0.0 2.0
# WARNING level with no output 2.78E3
# WARNING Unbalanced level 2.78E3:TimeQuantity(3.13 MEV,20) in=0.057999999999999996 out=0.0 2.0
# WARNING level with no output 14010
# WARNING Unbalanced level 14010:TimeQuantity(0.39 MEV,11) in=0.0016 out=0.0 2.0
# WARNING level with no output 14655.0
# WARNING Unbalanced level 14655.0:TimeQuantity(377 EV,38) in=1.0E-4 out=0.0 2.0
# WARNING level with no output 2345
# WARNING Unbalanced level 2345:TimeQuantity(81 KEV,5) in=0.304 out=0.0 2.0
# WARNING level with no output 12160
# WARNING Unbalanced level 12160:TimeQuantity(455 KEV,20) in=0.059000000000000004 out=0.0 2.0
# WARNING record without gamma normalization specified
# WARNING Bad linkage 11BE B- DECAY Quantity(7282.92,null)
# WARNING Bad linkage 11BE B- DECAY Quantity(7974.73,null)
# WARNING level with no output 9876
# WARNING Unbalanced level 9876:TimeQuantity(,null) in=0.031 out=0.0 2.0
# WARNING Unbalanced level 5020.31:TimeQuantity(,null) in=0.04282 out=1.0 1.8357530542183693
# WARNING Unbalanced level 6791.80:TimeQuantity(,null) in=0.0647 out=1.0 1.7569268338499109
# WARNING Unbalanced level 2124.693:TimeQuantity(,null) in=1.2750000000000001 out=1.0 0.24175824175824184
# WARNING Unbalanced level 7977.84:TimeQuantity(,null) in=0.04 out=1.0025 1.8465227817745802
# WARNING Unbalanced level 4444.89:TimeQuantity(,null) in=5.4E-4 out=1.0 1.997841165770484
# WARNING Unbalanced level 7285.51:TimeQuantity(,null) in=0.0088 out=0.87 1.9599453800637232
# WARNING Unbalanced level 7657.8:TimeQuantity(9.3 EV,9) in=0.0054 out=2.3E-6 1.9982970216389313
# WARNING level with no output 10.3E+3
# WARNING Unbalanced level 10.3E+3:TimeQuantity(3.0 MEV,7) in=6.2E-4 out=0.0 2.0
# WARNING level with no output 12710
# WARNING Unbalanced level 12710:TimeQuantity(18.1 EV,28) in=2.5999999999999997E-6 out=0.0 2.0
# WARNING level with no output 10.3E+3
# WARNING Unbalanced level 10.3E+3:TimeQuantity(3.0 MEV,7) in=0.004030000000000001 out=0.0 2.0
# WARNING Unbalanced level 7654.07:TimeQuantity(9.3 EV,9) in=0.0141 out=5.9E-6 1.9983269412089977
# WARNING level with no output 12710
# WARNING Unbalanced level 12710:TimeQuantity(18.1 EV,28) in=0.0012 out=0.0 2.0
# WARNING level with no output 15110
# WARNING Unbalanced level 15110:TimeQuantity(43.6 EV,10) in=2.3E-5 out=0.0 2.0
# WARNING Bad linkage 13B B- DECAY Quantity(8857,20)
# WARNING Bad linkage 13B B- DECAY Quantity(9893,5)
# WARNING Unbalanced level 3853.807:TimeQuantity(,null) in=0.006999999999999999 out=0.00809 0.14446653412856206
# WARNING Unbalanced level 3089.443:TimeQuantity(,null) in=0.01057 out=0.006999999999999999 0.40637450199203196
# WARNING level with no output 10360
# WARNING Unbalanced level 10360:TimeQuantity(,null) in=2.0E-4 out=0.0 2.0
# WARNING level with no output 3502
# WARNING Unbalanced level 3502:TimeQuantity(,null) in=0.098 out=0.0 2.0
# WARNING level with no output 8918
# WARNING Unbalanced level 8918:TimeQuantity(,null) in=0.0060999999999999995 out=0.0 2.0
# WARNING level with no output 9476
# WARNING Unbalanced level 9476:TimeQuantity(,null) in=0.0016 out=0.0 2.0
# WARNING level with no output 7376
# WARNING Unbalanced level 7376:TimeQuantity(,null) in=0.0018 out=0.0 2.0
# WARNING level with no output 1280
# WARNING Unbalanced level 1280:TimeQuantity(49 KEV,2) in=0.91 out=0.0 2.0
# WARNING level with no output 740
# WARNING Unbalanced level 740:TimeQuantity(,null) in=0.006 out=0.0 2.0
# WARNING Beta without NB specified
# WARNING level with no output 7341
# WARNING Unbalanced level 7341:TimeQuantity(111 FS,42) in=0.1 out=0.0 2.0
# WARNING level with no output 6093.8
# WARNING Unbalanced level 6093.8:TimeQuantity(7 FS,LT) in=0.79 out=0.0 2.0
# WARNING level with no output 6728.2
# WARNING Unbalanced level 6728.2:TimeQuantity(66 PS,8) in=0.08199999999999999 out=0.0 2.0
# WARNING Bad linkage 15C B- DECAY Quantity(8310.15,3)
# WARNING Bad linkage 15C B- DECAY Quantity(8568.77,12)
# WARNING Bad linkage 15C B- DECAY Quantity(9046.78,7)
# WARNING Unbalanced level 5270.155:TimeQuantity(,null) in=1.2057999999999999E-4 out=3.7000000000000005E-5 1.060794517070694
# WARNING Unbalanced level 6323.78:TimeQuantity(,null) in=7.504000000000001E-5 out=5.4999999999999995E-5 0.3082128575822827
# WARNING Decay to multiple daughters
# WARNING Bad linkage 16N B- DECAY Quantity(8869.3,5)
# WARNING level with no output 9585
# WARNING Unbalanced level 9585:TimeQuantity(,null) in=1.1999999999999999E-5 out=0.0 2.0
# WARNING level with no output 9844.5
# WARNING Unbalanced level 9844.5:TimeQuantity(,null) in=6.5E-9 out=0.0 2.0
# WARNING Unbalanced level 8871.9:TimeQuantity(,null) in=0.0106 out=0.01185 0.11135857461024494
# No relative intensity on Gamma 6048.2
# WARNING level with no output 2710
# WARNING Unbalanced level 2710:TimeQuantity(0.04 MEV,1) in=0.33 out=0.0 2.0
# WARNING level with no output 6080
# WARNING Unbalanced level 6080:TimeQuantity(2.5 MEV,7) in=0.04 out=0.0 2.0
# WARNING level with no output 4050
# WARNING Unbalanced level 4050:TimeQuantity(0.06 MEV,6) in=0.015 out=0.0 2.0
# WARNING level with no output 4780
# WARNING Unbalanced level 4780:TimeQuantity(0.3 MEV,3) in=0.009000000000000001 out=0.0 2.0
# WARNING level with no output 3930
# WARNING Unbalanced level 3930:TimeQuantity(0.16 MEV,4) in=0.2 out=0.0 2.0
# WARNING Unbalanced level 1906.8:TimeQuantity(,null) in=0.193 out=0.09100000000000001 0.7183098591549295
# WARNING Unbalanced level 1849.6:TimeQuantity(,null) in=0.28600000000000003 out=0.254 0.11851851851851862
# WARNING level with no output 5869.62
# WARNING Unbalanced level 5869.62:TimeQuantity(6.6 KEV,7) in=0.0015 out=0.0 2.0
# WARNING level with no output 6361.5
# WARNING Unbalanced level 6361.5:TimeQuantity(126 KEV,14) in=8.0E-4 out=0.0 2.0
# WARNING level with no output 5086.8
# WARNING Unbalanced level 5086.8:TimeQuantity(90 KEV,3) in=0.005699999999999999 out=0.0 2.0
# WARNING level with no output 4551.8
# WARNING Unbalanced level 4551.8:TimeQuantity(38.7 KEV,28) in=0.37799999999999995 out=0.0 2.0
# WARNING level with no output 8200
# WARNING Unbalanced level 8200:TimeQuantity(61 KEV,10) in=1.3E-4 out=0.0 2.0
# WARNING level with no output 5387.1
# WARNING Unbalanced level 5387.1:TimeQuantity(37.1 KEV,24) in=0.5031 out=0.0 2.0
# WARNING level with no output 7992
# WARNING Unbalanced level 7992:TimeQuantity(270 KEV,27) in=2.6E-4 out=0.0 2.0
# WARNING level with no output 5732.07
# WARNING Unbalanced level 5732.07:TimeQuantity(1 KEV,LT) in=0.0023 out=0.0 2.0
# WARNING level with no output 7543
# WARNING Unbalanced level 7543:TimeQuantity(500 KEV,50) in=0.0034999999999999996 out=0.0 2.0
# WARNING level with no output 5931.6
# WARNING Unbalanced level 5931.6:TimeQuantity(32 KEV,3) in=0.0669 out=0.0 2.0
# WARNING level with no output 870.756
# WARNING Unbalanced level 870.756:TimeQuantity(179.6 PS,27) in=3.4E-4 out=0.0 2.0
# WARNING Bad linkage 17NE B+ DECAY Quantity(10695,null)
# WARNING level with no output 4640
# WARNING Unbalanced level 4640:TimeQuantity(,null) in=0.141 out=0.0 2.0
# WARNING level with no output 10030
# WARNING Unbalanced level 10030:TimeQuantity(,null) in=0.0064 out=0.0 2.0
# WARNING level with no output 10660
# WARNING Unbalanced level 10660:TimeQuantity(,null) in=0.008100000000000001 out=0.0 2.0
# WARNING level with no output 6037
# WARNING Unbalanced level 6037:TimeQuantity(,null) in=0.0747 out=0.0 2.0
# WARNING level with no output 8436
# WARNING Unbalanced level 8436:TimeQuantity(59 KEV,10) in=0.0554 out=0.0 2.0
# WARNING level with no output 8075
# WARNING Unbalanced level 8075:TimeQuantity(53 KEV,10) in=0.07440000000000001 out=0.0 2.0
# WARNING level with no output 1091E1
# WARNING Unbalanced level 1091E1:TimeQuantity(,null) in=0.007850000000000001 out=0.0 2.0
# WARNING level with no output 8825
# WARNING Unbalanced level 8825:TimeQuantity(500 KEV,40) in=0.0482 out=0.0 2.0
# WARNING level with no output 12250
# WARNING Unbalanced level 12250:TimeQuantity(,null) in=2.1E-5 out=0.0 2.0
# WARNING level with no output 3104
# WARNING Unbalanced level 3104:TimeQuantity(,null) in=0.00154 out=0.0 2.0
# WARNING Unbalanced level 11192.9:TimeQuantity(,null) in=0.0076500000000000005 out=2.1E-4 1.8931297709923665
# WARNING level with no output 8200
# WARNING Unbalanced level 8200:TimeQuantity(,null) in=0.0417 out=0.0 2.0
# WARNING level with no output 9450
# WARNING Unbalanced level 9450:TimeQuantity(,null) in=0.0189 out=0.0 2.0
# WARNING level with no output 5488
# WARNING Unbalanced level 5488:TimeQuantity(,null) in=0.493 out=0.0 2.0
# WARNING Decay to multiple daughters
# WARNING Unbalanced level 1080.54:TimeQuantity(,null) in=2.1E-5 out=2.2599999999999997E-5 0.07339449541284396
# WARNING Beta without NB specified
# Bad quantity 581+X
# WARNING level with no output 4763+Y
# WARNING Unbalanced level 4763+Y:TimeQuantity(,null) in=0.16 out=0.0 2.0
# Bad quantity 581+X
# WARNING unable to find isomer for level 6400 0.0
# WARNING Decay to multiple daughters
# WARNING level with no output 8740.8
# WARNING Unbalanced level 8740.8:TimeQuantity(,null) in=0.067 out=0.0 2.0
# WARNING level with no output 7050.8
# WARNING Unbalanced level 7050.8:TimeQuantity(,null) in=0.17300000000000001 out=0.0 2.0
# WARNING level with no output 6403.1
# WARNING Unbalanced level 6403.1:TimeQuantity(,null) in=0.040999999999999995 out=0.0 2.0
# WARNING level with no output 10572
# WARNING Unbalanced level 10572:TimeQuantity(,null) in=0.012 out=0.0 2.0
# WARNING level with no output 4432.4
# WARNING Unbalanced level 4432.4:TimeQuantity(,null) in=0.10400000000000001 out=0.0 2.0
# WARNING level with no output 3999.
# WARNING Unbalanced level 3999.:TimeQuantity(,null) in=1.0E-5 out=0.0 2.0
# WARNING Unbalanced level 109.89:TimeQuantity(,null) in=0.0271333 out=0.0254 0.06598862055115517
# WARNING level with no output 1459.
# WARNING Unbalanced level 1459.:TimeQuantity(,null) in=1.0E-4 out=0.0 2.0
# WARNING level with no output 4550.
# WARNING Unbalanced level 4550.:TimeQuantity(,null) in=1.0E-5 out=0.0 2.0
# WARNING Unbalanced level 4377.700:TimeQuantity(,null) in=9.84E-4 out=7.920000000000001E-4 0.2162162162162162
# WARNING level with no output 4033.
# WARNING Unbalanced level 4033.:TimeQuantity(,null) in=1.0E-5 out=0.0 2.0
# WARNING Unbalanced level 2779.849:TimeQuantity(,null) in=2.0E-5 out=1.89E-4 1.6172248803827751
# WARNING level with no output 0+X
# WARNING Unbalanced level 0+X:TimeQuantity(,null) in=0.65 out=0.0 2.0
# WARNING Energy 3497.0: RI not specified
# WARNING Energy 5896.0: RI not specified
# WARNING level with no output 9024
# WARNING Unbalanced level 9024:TimeQuantity(,null) in=0.052000000000000005 out=0.0 2.0
# WARNING Unbalanced level 4071.1:TimeQuantity(,null) in=0.059000000000000004 out=0.093 0.4473684210526315
# WARNING level with no output 9884
# WARNING Unbalanced level 9884:TimeQuantity(,null) in=0.149 out=0.0 2.0
# WARNING level with no output 10587
# WARNING Unbalanced level 10587:TimeQuantity(,null) in=0.044000000000000004 out=0.0 2.0
# WARNING level with no output 8860
# WARNING Unbalanced level 8860:TimeQuantity(,null) in=0.076 out=0.0 2.0
# WARNING Unbalanced level 1673.60:TimeQuantity(7.28 PS,28) in=0.473 out=0.516 0.08695652173913052
# WARNING level with no output 12521
# WARNING Unbalanced level 12521:TimeQuantity(,null) in=0.025 out=0.0 2.0
# WARNING level with no output 12957
# WARNING Unbalanced level 12957:TimeQuantity(,null) in=0.045 out=0.0 2.0
# WARNING level with no output 7568.5
# WARNING Unbalanced level 7568.5:TimeQuantity(,null) in=0.077 out=0.0 2.0
# WARNING level with no output 10841
# WARNING Unbalanced level 10841:TimeQuantity(,null) in=0.043 out=0.0 2.0
# No relative intensity on Gamma 3497
# No relative intensity on Gamma 5896
# WARNING Unbalanced level 1843.80:TimeQuantity(46 FS,3) in=2.0E-5 out=1.9E-5 0.051282051282051315
# WARNING Energy 5090.0: RI not specified
# WARNING Energy 6198.7: RI not specified
# WARNING Energy 7831.8: RI not specified
# WARNING Energy 7848.0: RI not specified
# WARNING Bad linkage 20NA B+ DECAY:1 Quantity(8237,4)
# WARNING Bad linkage 20NA B+ DECAY:1 Quantity(8638,3)
# WARNING Bad linkage 20NA B+ DECAY:1 Quantity(9248,3)
# WARNING Bad linkage 20NA B+ DECAY:1 Quantity(9626.1,19)
# WARNING Bad linkage 20NA B+ DECAY:1 Quantity(11258.9,19)
# WARNING Unbalanced level 10884:TimeQuantity(,null) in=0.00117 out=3.5099999999999997E-4 1.076923076923077
# WARNING level with no output 8058
# WARNING Unbalanced level 8058:TimeQuantity(,null) in=1.19E-4 out=0.0 2.0
# WARNING level with no output 10840
# WARNING Unbalanced level 10840:TimeQuantity(,null) in=0.0017399999999999998 out=0.0 2.0
# WARNING level with no output 10941
# WARNING Unbalanced level 10941:TimeQuantity(,null) in=1.19E-4 out=0.0 2.0
# WARNING Unbalanced level 9873:TimeQuantity(,null) in=2.8000000000000003E-4 out=2.54E-4 0.0973782771535582
# WARNING level with no output 10578
# WARNING Unbalanced level 10578:TimeQuantity(,null) in=8.83E-4 out=0.0 2.0
# WARNING level with no output 11856
# WARNING Unbalanced level 11856:TimeQuantity(,null) in=1.6E-5 out=0.0 2.0
# WARNING level with no output 9483
# WARNING Unbalanced level 9483:TimeQuantity(,null) in=0.00241 out=0.0 2.0
# WARNING Unbalanced level 7421.9:TimeQuantity(,null) in=0.15963000000000002 out=3.0E-5 1.999248402856069
# WARNING level with no output 7833.4
# WARNING Unbalanced level 7833.4:TimeQuantity(,null) in=0.005829999999999999 out=0.0 2.0
# WARNING Unbalanced level 10274:TimeQuantity(,null) in=0.028769999999999997 out=4.14E-4 1.9432565789473684
# WARNING level with no output 6725
# WARNING level with no output 11295
# WARNING Unbalanced level 11295:TimeQuantity(,null) in=2.63E-4 out=0.0 2.0
# WARNING level with no output 11116
# WARNING Unbalanced level 11116:TimeQuantity(,null) in=8.7E-5 out=0.0 2.0
# WARNING level with no output 9196
# WARNING Unbalanced level 9196:TimeQuantity(,null) in=6.25E-4 out=0.0 2.0
# WARNING level with no output 6706
# WARNING Unbalanced level 6706:TimeQuantity(,null) in=3.2E-5 out=0.0 2.0
# No relative intensity on Gamma 5090
# No relative intensity on Gamma 6198.7
# No relative intensity on Gamma 7831.8
# No relative intensity on Gamma 7848
# WARNING Bad linkage 20NA B+ DECAY:2 Quantity(8237,4)
# WARNING Bad linkage 20NA B+ DECAY:2 Quantity(9870,4)
# WARNING Bad linkage 20NA B+ DECAY:2 Quantity(8638,3)
# WARNING Bad linkage 20NA B+ DECAY:2 Quantity(10271,3)
# WARNING Bad linkage 20NA B+ DECAY:2 Quantity(9248,3)
# WARNING Bad linkage 20NA B+ DECAY:2 Quantity(9626.1,19)
# WARNING Bad linkage 20NA B+ DECAY:2 Quantity(11258.9,19)
# WARNING level with no output 8800
# WARNING Unbalanced level 8800:TimeQuantity(,null) in=3.4E-4 out=0.0 2.0
# WARNING level with no output 7829.0
# WARNING Unbalanced level 7829.0:TimeQuantity(,null) in=0.006781000000000001 out=0.0 2.0
# WARNING Unbalanced level 9873:TimeQuantity(,null) in=2.7E-4 out=2.29E-4 0.16432865731462923
# WARNING level with no output 9487
# WARNING Unbalanced level 9487:TimeQuantity(,null) in=0.00247 out=0.0 2.0
# WARNING Unbalanced level 10884:TimeQuantity(,null) in=3.9E-4 out=1.6999999999999999E-4 0.7857142857142858
# WARNING Unbalanced level 4247.7:TimeQuantity(,null) in=6.6E-5 out=2.6E-5 0.8695652173913045
# WARNING Unbalanced level 5621.4:TimeQuantity(,null) in=6.75E-4 out=6.199999999999999E-4 0.08494208494208517
# WARNING level with no output 7421.9
# WARNING Unbalanced level 7421.9:TimeQuantity(,null) in=0.16610699999999998 out=0.0 2.0
# WARNING level with no output 11885
# WARNING Unbalanced level 11885:TimeQuantity(,null) in=1.6E-5 out=0.0 2.0
# WARNING Unbalanced level 4966.51:TimeQuantity(,null) in=4.4E-4 out=3.722E-4 0.1669539522285152
# WARNING level with no output 11320
# WARNING Unbalanced level 11320:TimeQuantity(,null) in=3.5999999999999997E-4 out=0.0 2.0
# WARNING level with no output 10843
# WARNING Unbalanced level 10843:TimeQuantity(,null) in=0.00193 out=0.0 2.0
# WARNING level with no output 10584
# WARNING Unbalanced level 10584:TimeQuantity(,null) in=8.699999999999999E-4 out=0.0 2.0
# WARNING unable to find isomer for level 984.25 0.0
# WARNING Decay to multiple daughters
# WARNING level with no output 6.91E3
# WARNING Unbalanced level 6.91E3:TimeQuantity(,null) in=0.045 out=0.0 2.0
# WARNING level with no output 6.80E3
# WARNING Unbalanced level 6.80E3:TimeQuantity(,null) in=0.084 out=0.0 2.0
# WARNING level with no output 6.14E3
# WARNING Unbalanced level 6.14E3:TimeQuantity(,null) in=0.063 out=0.0 2.0
# WARNING level with no output 9.02E3
# WARNING Unbalanced level 9.02E3:TimeQuantity(,null) in=0.069 out=0.0 2.0
# WARNING level with no output 9.04E3
# WARNING Unbalanced level 9.04E3:TimeQuantity(,null) in=0.099 out=0.0 2.0
# WARNING Unbalanced level 350.727:TimeQuantity(,null) in=0.89522703975 out=0.008955 1.960384083707409
# WARNING level with no output 6170
# WARNING Unbalanced level 6170:TimeQuantity(,null) in=0.0014000000000000002 out=0.0 2.0
# WARNING level with no output 5020
# WARNING Unbalanced level 5020:TimeQuantity(,null) in=0.0253 out=0.0 2.0
# WARNING level with no output 8303
# WARNING Unbalanced level 8303:TimeQuantity(,null) in=0.0031 out=0.0 2.0
# WARNING level with no output 8827
# WARNING Unbalanced level 8827:TimeQuantity(,null) in=0.011899999999999999 out=0.0 2.0
# WARNING level with no output 8973
# WARNING Unbalanced level 8973:TimeQuantity(,null) in=0.0279 out=0.0 2.0
# WARNING level with no output 5867
# WARNING Unbalanced level 5867:TimeQuantity(,null) in=0.0062 out=0.0 2.0
# WARNING level with no output 4294
# WARNING Unbalanced level 4294:TimeQuantity(,null) in=0.054000000000000006 out=0.0 2.0
# WARNING level with no output 9280
# WARNING Unbalanced level 9280:TimeQuantity(,null) in=1.3E-5 out=0.0 2.0
# WARNING Unbalanced level 3544.0:TimeQuantity(,null) in=0.0045000000000000005 out=1.09E-4 1.9054024734215667
# WARNING level with no output 6341
# WARNING Unbalanced level 6341:TimeQuantity(,null) in=0.0086 out=0.0 2.0
# WARNING level with no output 5979
# WARNING Unbalanced level 5979:TimeQuantity(,null) in=0.004699999999999999 out=0.0 2.0
# WARNING level with no output 6512
# WARNING Unbalanced level 6512:TimeQuantity(,null) in=0.010700000000000001 out=0.0 2.0
# WARNING level with no output 8397
# WARNING Unbalanced level 8397:TimeQuantity(,null) in=0.0018 out=0.0 2.0
# WARNING level with no output 4468
# WARNING Unbalanced level 4468:TimeQuantity(,null) in=0.105 out=0.0 2.0
# WARNING level with no output 5380
# WARNING Unbalanced level 5380:TimeQuantity(,null) in=0.024300000000000002 out=0.0 2.0
# WARNING level with no output 5770
# WARNING Unbalanced level 5770:TimeQuantity(,null) in=0.0034000000000000002 out=0.0 2.0
# WARNING level with no output 6090
# WARNING Unbalanced level 6090:TimeQuantity(,null) in=0.0014000000000000002 out=0.0 2.0
# WARNING Beta without NB specified
# WARNING level with no output 10554
# WARNING Unbalanced level 10554:TimeQuantity(,null) in=0.066 out=0.0 2.0
# WARNING level with no output 8783
# WARNING Unbalanced level 8783:TimeQuantity(,null) in=0.13 out=0.0 2.0
# WARNING level with no output 13298
# WARNING Unbalanced level 13298:TimeQuantity(,null) in=0.096 out=0.0 2.0
# WARNING level with no output 7649
# WARNING Unbalanced level 7649:TimeQuantity(,null) in=0.12 out=0.0 2.0
# WARNING Gamma without destination Quantity(1874.2,10) null
# WARNING Unbalanced level 709.0:TimeQuantity(,null) in=0.97 out=1.13 0.15238095238095234
# WARNING Bad linkage 22F B- DECAY Quantity(3179.4,null)
# WARNING Unbalanced level 5910.1:TimeQuantity(,null) in=0.0125 out=0.0036 1.1055900621118016
# WARNING record missing NB specification
# WARNING Unbalanced level 5451.8:TimeQuantity(,null) in=0.059000000000000004 out=0.017 1.1052631578947367
# WARNING level with no output 6476
# WARNING Unbalanced level 6476:TimeQuantity(,null) in=0.0025 out=0.0 2.0
# WARNING level with no output 9518
# WARNING Unbalanced level 9518:TimeQuantity(,null) in=0.01 out=0.0 2.0
# WARNING level with no output 13018
# WARNING Unbalanced level 13018:TimeQuantity(,null) in=0.0033 out=0.0 2.0
# WARNING level with no output 9725
# WARNING Unbalanced level 9725:TimeQuantity(,null) in=0.0084 out=0.0 2.0
# WARNING level with no output 10678
# WARNING Unbalanced level 10678:TimeQuantity(,null) in=0.0029 out=0.0 2.0
# WARNING level with no output 14012
# WARNING Unbalanced level 14012:TimeQuantity(,null) in=0.019 out=0.0 2.0
# WARNING level with no output 8589
# WARNING Unbalanced level 8589:TimeQuantity(,null) in=0.0189 out=0.0 2.0
# WARNING Unbalanced level 1247.02:TimeQuantity(,null) in=0.34 out=0.38 0.11111111111111106
# WARNING level with no output 6307
# WARNING Unbalanced level 6307:TimeQuantity(,null) in=0.047 out=0.0 2.0
# WARNING level with no output 6724
# WARNING Unbalanced level 6724:TimeQuantity(,null) in=0.0075 out=0.0 2.0
# WARNING level with no output 7254
# WARNING Unbalanced level 7254:TimeQuantity(,null) in=0.0045000000000000005 out=0.0 2.0
# WARNING level with no output 6865
# WARNING Unbalanced level 6865:TimeQuantity(,null) in=0.03 out=0.0 2.0
# WARNING level with no output 9965
# WARNING Unbalanced level 9965:TimeQuantity(,null) in=0.0252 out=0.0 2.0
# WARNING level with no output 7132
# WARNING Unbalanced level 7132:TimeQuantity(,null) in=0.185 out=0.0 2.0
# WARNING level with no output 11309
# WARNING Unbalanced level 11309:TimeQuantity(,null) in=0.002 out=0.0 2.0
# WARNING level with no output 11410
# WARNING Unbalanced level 11410:TimeQuantity(,null) in=0.002 out=0.0 2.0
# WARNING level with no output 8416
# WARNING Unbalanced level 8416:TimeQuantity(,null) in=0.0489 out=0.0 2.0
# WARNING level with no output 7052
# WARNING Unbalanced level 7052:TimeQuantity(,null) in=0.008100000000000001 out=0.0 2.0
# WARNING level with no output 8339
# WARNING Unbalanced level 8339:TimeQuantity(,null) in=0.021099999999999997 out=0.0 2.0
# WARNING level with no output 8985
# WARNING Unbalanced level 8985:TimeQuantity(,null) in=0.0218 out=0.0 2.0
# WARNING level with no output 8004
# WARNING Unbalanced level 8004:TimeQuantity(,null) in=0.0064 out=0.0 2.0
# WARNING level with no output 10413
# WARNING Unbalanced level 10413:TimeQuantity(,null) in=0.003 out=0.0 2.0
# WARNING level with no output 7573
# WARNING Unbalanced level 7573:TimeQuantity(,null) in=0.0048 out=0.0 2.0
# WARNING level with no output 6221
# WARNING Unbalanced level 6221:TimeQuantity(,null) in=0.07400000000000001 out=0.0 2.0
# WARNING beta without intensity Quantity(,null)
# Bad quantity 7580+X
# Bad quantity 7580+X
# Bad quantity 7580+X
# Bad quantity 7580+X
# Bad quantity 7580+X
# Bad quantity 7580+X
# WARNING Bad linkage 23O B- DECAY (97 MS) Quantity(3868,15)
# Bad quantity 7580+X
# Bad quantity 7580+X
# Bad quantity 7580+X
# Bad quantity 7580+X
# WARNING Unbalanced level 3837:TimeQuantity(,null) in=0.021 out=0.027000000000000003 0.25000000000000006
# WARNING level with no output 7580+X
# WARNING Unbalanced level 7580+X:TimeQuantity(,null) in=0.07 out=0.0 2.0
# WARNING Unbalanced level 2926:TimeQuantity(,null) in=0.07900000000000001 out=0.07200000000000001 0.09271523178807954
# WARNING beta without intensity Quantity(,null)
# Bad quantity 5201+X
# Bad quantity 5201+X
# Bad quantity 5201+X
# Bad quantity 5201+X
# Bad quantity 5201+X
# Bad quantity 5201+X
# Bad quantity 5201+X
# Bad quantity 5201+X
# Bad quantity 5201+X
# Bad quantity 5201+X
# Bad quantity 5201+X
# Bad quantity 5201+X
# Bad quantity 5201+X
# WARNING Unbalanced level 1016.9:TimeQuantity(,null) in=0.0744 out=0.0603 0.20935412026726052
# WARNING level with no output 3836.35
# WARNING Unbalanced level 3836.35:TimeQuantity(,null) in=0.011000000000000001 out=0.0 2.0
# WARNING level with no output 5201+X
# WARNING Unbalanced level 5201+X:TimeQuantity(,null) in=0.14 out=0.0 2.0
# WARNING level with no output 3220.69
# WARNING Unbalanced level 3220.69:TimeQuantity(,null) in=0.012 out=0.0 2.0
# WARNING record without gamma normalization specified
# WARNING Energy 1598.0: RI not specified
# WARNING Energy 2053.0: RI not specified
# WARNING Energy 2453.7: RI not specified
# WARNING Energy 2905.0: RI not specified
# WARNING Energy 4084.0: RI not specified
# WARNING Energy 4629.0: RI not specified
# WARNING Energy 4835.0: RI not specified
# WARNING Energy 6122.4: RI not specified
# WARNING Energy 6533.9: RI not specified
# WARNING Energy 6575.0: RI not specified
# WARNING Energy 6985.4: RI not specified
# WARNING Decay to multiple daughters
# WARNING record missing NB specification
# WARNING Decay to multiple daughters
# Bad quantity 3810+X
# Bad quantity 3810+X
# Bad quantity 3810+X
# WARNING level with no output 3810+X
# WARNING Unbalanced level 3810+X:TimeQuantity(,null) in=0.42 out=0.0 2.0
# WARNING Unbalanced level 521.6:TimeQuantity(,null) in=0.18 out=0.21 0.15384615384615383
# WARNING Energy 1981.6: RI not specified
# WARNING level with no output 1981.6
# No relative intensity on Gamma 1981.6
# WARNING Unbalanced level 472.2071:TimeQuantity(20.18 MS,10) in=0.0 out=1.0 2.0
# WARNING Unbalanced level 1368.667:TimeQuantity(,null) in=0.9993525000000001 out=0.03 1.8834218598585033
# WARNING Unbalanced level 4238.38:TimeQuantity(,null) in=2.1E-5 out=1.09E-5 0.6332288401253917
# WARNING Bad linkage 24AL EC DECAY (2.053 S) Quantity(5060.7,8)
# WARNING Bad linkage 24AL EC DECAY (2.053 S) Quantity(9450.1,4)
# WARNING Bad linkage 24AL EC DECAY (2.053 S) Quantity(9943.5,15)
# WARNING Gamma without destination Quantity(587.95,6) null
# WARNING Gamma without destination Quantity(909.09,6) null
# WARNING Gamma without destination Quantity(1117,null) null
# WARNING Gamma without destination Quantity(1172,null) null
# WARNING Gamma without destination Quantity(1298,null) null
# WARNING Gamma without destination Quantity(1340,null) null
# WARNING Gamma without destination Quantity(1434.11,20) null
# WARNING Gamma without destination Quantity(1468,null) null
# WARNING Gamma without destination Quantity(1633,null) null
# WARNING Gamma without destination Quantity(2127.51,20) null
# WARNING Gamma without destination Quantity(2222,null) null
# WARNING Gamma without destination Quantity(2566.96,20) null
# WARNING Gamma without destination Quantity(2630,null) null
# WARNING Gamma without destination Quantity(6128,null) null
# WARNING Gamma without destination Quantity(7648,null) null
# WARNING Gamma without destination Quantity(7850,null) null
# WARNING Gamma without destination Quantity(9962,null) null
# WARNING level with no output 12162
# WARNING Unbalanced level 12162:TimeQuantity(,null) in=7.5E-6 out=0.0 2.0
# WARNING level with no output 11698.2
# WARNING Unbalanced level 11698.2:TimeQuantity(,null) in=2.6E-4 out=0.0 2.0
# WARNING Unbalanced level 9457.81:TimeQuantity(,null) in=0.0 out=2.0E-4 2.0
# WARNING level with no output 12051.3
# WARNING Unbalanced level 12051.3:TimeQuantity(,null) in=1.1E-6 out=0.0 2.0
# WARNING level with no output 11216.69
# WARNING Unbalanced level 11216.69:TimeQuantity(,null) in=7.2E-5 out=0.0 2.0
# WARNING level with no output 12119.0
# WARNING Unbalanced level 12119.0:TimeQuantity(,null) in=1.0E-5 out=0.0 2.0
# WARNING level with no output 12975
# WARNING Unbalanced level 12975:TimeQuantity(,null) in=2.0000000000000002E-7 out=0.0 2.0
# WARNING Bad linkage 24AL EC DECAY (130.7 MS) Quantity(9825.9,20)
# WARNING Bad linkage 24AL EC DECAY (130.7 MS) Quantity(9963.0,15)
# WARNING level with no output 12404.9
# WARNING Unbalanced level 12404.9:TimeQuantity(,null) in=7.998848000000001E-7 out=0.0 2.0
# WARNING level with no output 11457
# WARNING Unbalanced level 11457:TimeQuantity(,null) in=8.998704E-5 out=0.0 2.0
# WARNING level with no output 10917.2
# WARNING Unbalanced level 10917.2:TimeQuantity(,null) in=8.998704E-7 out=0.0 2.0
# WARNING level with no output 11522
# WARNING Unbalanced level 11522:TimeQuantity(,null) in=1.6997552E-5 out=0.0 2.0
# WARNING level with no output 12467
# WARNING Unbalanced level 12467:TimeQuantity(,null) in=3.9994240000000004E-7 out=0.0 2.0
# WARNING level with no output 10679.7
# WARNING Unbalanced level 10679.7:TimeQuantity(,null) in=8.998704E-6 out=0.0 2.0
# WARNING level with no output 11018
# WARNING Unbalanced level 11018:TimeQuantity(,null) in=1.5997696000000003E-4 out=0.0 2.0
# WARNING Unbalanced level 425.81:TimeQuantity(130.7 MS,13) in=0.0 out=1.0 2.0
# WARNING Energy 425.81: RI not specified
# WARNING Energy 662.5: RI not specified
# WARNING level with no output 6243
# WARNING Unbalanced level 6243:TimeQuantity(,null) in=0.022000000000000002 out=0.0 2.0
# WARNING level with no output 6487
# WARNING Unbalanced level 6487:TimeQuantity(,null) in=0.0026 out=0.0 2.0
# WARNING level with no output 1088.3
# WARNING Unbalanced level 1088.3:TimeQuantity(,null) in=0.239 out=0.0 2.0
# WARNING level with no output 2991
# WARNING Unbalanced level 2991:TimeQuantity(,null) in=0.057999999999999996 out=0.0 2.0
# WARNING level with no output 5801
# WARNING Unbalanced level 5801:TimeQuantity(,null) in=0.01 out=0.0 2.0
# WARNING level with no output 4976
# WARNING Unbalanced level 4976:TimeQuantity(,null) in=0.008 out=0.0 2.0
# WARNING level with no output 4389
# WARNING Unbalanced level 4389:TimeQuantity(,null) in=0.0049 out=0.0 2.0
# WARNING level with no output 4700
# WARNING Unbalanced level 4700:TimeQuantity(,null) in=0.011000000000000001 out=0.0 2.0
# WARNING level with no output 5953
# WARNING Unbalanced level 5953:TimeQuantity(,null) in=0.099 out=0.0 2.0
# WARNING level with no output 3364
# WARNING Unbalanced level 3364:TimeQuantity(,null) in=0.11 out=0.0 2.0
# WARNING level with no output 6735
# WARNING Unbalanced level 6735:TimeQuantity(,null) in=7.000000000000001E-4 out=0.0 2.0
# WARNING level with no output 425.81
# WARNING Unbalanced level 425.81:TimeQuantity(130.7 MS,13) in=0.41 out=0.0 2.0
# WARNING level with no output 5382
# WARNING Unbalanced level 5382:TimeQuantity(,null) in=0.0068000000000000005 out=0.0 2.0
# No relative intensity on Gamma 425.81
# No relative intensity on Gamma 662.5
# WARNING Unbalanced level 3316.4:TimeQuantity(,null) in=0.21000000000000002 out=0.17 0.21052631578947373
# WARNING record without gamma normalization specified
# WARNING level with no output 3844
# WARNING Unbalanced level 3844:TimeQuantity(,null) in=0.004 out=0.0 2.0
# WARNING level with no output 7892
# WARNING Unbalanced level 7892:TimeQuantity(,null) in=0.128 out=0.0 2.0
# WARNING level with no output 8193
# WARNING Unbalanced level 8193:TimeQuantity(20 KEV,20) in=0.012 out=0.0 2.0
# WARNING level with no output 7107
# WARNING Unbalanced level 7107:TimeQuantity(33 KEV,5) in=0.037000000000000005 out=0.0 2.0
# WARNING level with no output 9073
# WARNING Unbalanced level 9073:TimeQuantity(,null) in=0.0021 out=0.0 2.0
# WARNING level with no output 6170
# WARNING Unbalanced level 6170:TimeQuantity(,null) in=0.0032 out=0.0 2.0
# WARNING Unbalanced level 452:TimeQuantity(,null) in=0.153 out=0.184 0.18397626112759646
# WARNING level with no output 4189
# WARNING Unbalanced level 4189:TimeQuantity(,null) in=0.029900000000000003 out=0.0 2.0
# WARNING level with no output 6620
# WARNING Unbalanced level 6620:TimeQuantity(,null) in=0.0016 out=0.0 2.0
# WARNING level with no output 4908
# WARNING Unbalanced level 4908:TimeQuantity(,null) in=0.006 out=0.0 2.0
# WARNING level with no output 5802
# WARNING Unbalanced level 5802:TimeQuantity(,null) in=0.017 out=0.0 2.0
# WARNING level with no output 6871
# WARNING Unbalanced level 6871:TimeQuantity(,null) in=0.005 out=0.0 2.0
# WARNING level with no output 5597
# WARNING Unbalanced level 5597:TimeQuantity(56 KEV,20) in=0.005600000000000001 out=0.0 2.0
# WARNING level with no output 4582
# WARNING Unbalanced level 4582:TimeQuantity(,null) in=0.032 out=0.0 2.0
# WARNING level with no output 7678
# WARNING Unbalanced level 7678:TimeQuantity(,null) in=0.0034000000000000002 out=0.0 2.0
# WARNING level with no output 2672
# WARNING Unbalanced level 2672:TimeQuantity(,null) in=0.048 out=0.0 2.0
# WARNING level with no output 7255
# WARNING Unbalanced level 7255:TimeQuantity(,null) in=0.01 out=0.0 2.0
# WARNING Decay to multiple daughters
# WARNING Energy 2901.0: RI not specified
# WARNING Energy 4153.0: RI not specified
# Bad quantity SN+X
# Bad quantity SN+X
# Bad quantity SN+X
# WARNING Gamma without destination Quantity(2901,null) null
# WARNING Gamma without destination Quantity(4153,null) null
# WARNING level with no output SN+X
# WARNING Unbalanced level SN+X:TimeQuantity(,null) in=0.135 out=0.0 2.0
# No relative intensity on Gamma 2901
# No relative intensity on Gamma 4153
# WARNING Energy 2901.0: RI not specified
# WARNING Energy 4153.0: RI not specified
# Bad quantity SN+X
# Bad quantity SN+X
# Bad quantity SN+X
# WARNING Gamma without destination Quantity(2901,null) null
# WARNING Gamma without destination Quantity(4153,null) null
# WARNING level with no output SN+X
# WARNING Unbalanced level SN+X:TimeQuantity(,null) in=0.135 out=0.0 2.0
# No relative intensity on Gamma 2901
# No relative intensity on Gamma 4153
# WARNING Energy 2017.9: RI not specified
# Bad quantity SN+X
# Bad quantity SN+X
# Bad quantity SN+X
# WARNING level with no output SN+X
# WARNING Unbalanced level SN+X:TimeQuantity(,null) in=0.1200096 out=0.0 2.0
# WARNING level with no output 2017.83
# WARNING Unbalanced level 2017.83:TimeQuantity(,null) in=0.02300184 out=0.0 2.0
# No relative intensity on Gamma 2017.9
# WARNING Bad linkage 26NE B- DECAY Quantity(153,3)
# WARNING Bad linkage 26NE B- DECAY Quantity(2486,4)
# WARNING record missing NB specification
# WARNING Unbalanced level 2740.03:TimeQuantity(,null) in=6.180000000000001E-4 out=6.761131352E-4 0.0898115220676108
# WARNING Unbalanced level 1759.034:TimeQuantity(,null) in=0.0 out=2.1364000000000002E-4 2.0
# WARNING Unbalanced level 3723.81:TimeQuantity(,null) in=1.3E-5 out=4.2518338500000005E-5 1.063372546712651
# WARNING level with no output 8254
# WARNING Unbalanced level 8254:TimeQuantity(,null) in=0.0067 out=0.0 2.0
# WARNING level with no output 10299
# WARNING Unbalanced level 10299:TimeQuantity(,null) in=0.0067 out=0.0 2.0
# WARNING Unbalanced level 5928.5:TimeQuantity(,null) in=0.18 out=0.0018 1.9603960396039606
# WARNING level with no output 10827
# WARNING Unbalanced level 10827:TimeQuantity(,null) in=0.0044 out=0.0 2.0
# WARNING level with no output 10688
# WARNING Unbalanced level 10688:TimeQuantity(,null) in=0.0024 out=0.0 2.0
# WARNING Unbalanced level 2786.31:TimeQuantity(,null) in=0.074 out=0.052000000000000005 0.3492063492063491
# WARNING level with no output 6295
# WARNING Unbalanced level 6295:TimeQuantity(,null) in=0.0078000000000000005 out=0.0 2.0
# WARNING level with no output 7501
# WARNING Unbalanced level 7501:TimeQuantity(,null) in=0.024 out=0.0 2.0
# WARNING level with no output 9370
# WARNING Unbalanced level 9370:TimeQuantity(,null) in=6.0E-4 out=0.0 2.0
# WARNING level with no output 7606
# WARNING Unbalanced level 7606:TimeQuantity(,null) in=0.006500000000000001 out=0.0 2.0
# WARNING level with no output 13015
# WARNING Unbalanced level 13015:TimeQuantity(,null) in=0.053 out=0.0 2.0
# WARNING level with no output 9725
# WARNING Unbalanced level 9725:TimeQuantity(,null) in=0.0059 out=0.0 2.0
# WARNING level with no output 9433
# WARNING Unbalanced level 9433:TimeQuantity(,null) in=0.035 out=0.0 2.0
# WARNING Unbalanced level 4186.85:TimeQuantity(,null) in=0.0309 out=0.027999999999999997 0.09847198641765717
# WARNING level with no output 8563
# WARNING Unbalanced level 8563:TimeQuantity(,null) in=0.0027 out=0.0 2.0
# WARNING level with no output 6765
# WARNING Unbalanced level 6765:TimeQuantity(,null) in=0.015 out=0.0 2.0
# WARNING Unbalanced level 3842.2:TimeQuantity(,null) in=0.0168 out=0.013999999999999999 0.18181818181818185
# WARNING level with no output 6384
# WARNING Unbalanced level 6384:TimeQuantity(,null) in=0.017 out=0.0 2.0
# WARNING level with no output 10405
# WARNING Unbalanced level 10405:TimeQuantity(,null) in=0.0031 out=0.0 2.0
# WARNING level with no output 7962
# WARNING Unbalanced level 7962:TimeQuantity(,null) in=0.009899999999999999 out=0.0 2.0
# WARNING Unbalanced level 4139.18:TimeQuantity(,null) in=0.0178 out=0.013000000000000001 0.31168831168831157
# WARNING level with no output 8156
# WARNING Unbalanced level 8156:TimeQuantity(,null) in=0.0011 out=0.0 2.0
# WARNING Unbalanced level 2192.1:TimeQuantity(,null) in=0.009000000000000001 out=0.0098 0.08510638297872325
# WARNING Unbalanced level 4355.2:TimeQuantity(,null) in=0.03 out=0.032 0.06451612903225812
# WARNING Unbalanced level 3781.3:TimeQuantity(,null) in=0.03 out=0.032 0.06451612903225812
# WARNING Beta without NB specified
# WARNING Unbalanced level 1014.54:TimeQuantity(,null) in=1.8999999999999998E-4 out=2.9E-4 0.4166666666666668
# WARNING Unbalanced level 843.77:TimeQuantity(,null) in=1.9E-4 out=4.0E-5 1.3043478260869565
# WARNING Unbalanced level 3004.2:TimeQuantity(,null) in=5.0E-6 out=1.0E-5 0.6666666666666666
# WARNING unable to find isomer for level 12752 0.0
# WARNING Decay to multiple daughters
# WARNING Energy 1459.0: RI not specified
# WARNING level with no output 10270
# WARNING Unbalanced level 10270:TimeQuantity(,null) in=0.037000000000000005 out=0.0 2.0
# WARNING Unbalanced level 1131.2:TimeQuantity(,null) in=0.0285 out=0.0269 0.05776173285198558
# WARNING Unbalanced level 55.2:TimeQuantity(,null) in=0.25529999999999997 out=0.146 0.5447296287067032
# WARNING Unbalanced level 1254.2:TimeQuantity(,null) in=0.049 out=0.0443 0.10075026795284037
# WARNING level with no output 3543
# WARNING Unbalanced level 3543:TimeQuantity(,null) in=0.12 out=0.0 2.0
# ...
# WARNING Gamma without destination Quantity(1706.1,4) null
# WARNING Gamma without destination Quantity(1718.0,8) null
# WARNING Gamma without destination Quantity(1721.6,5) null
# WARNING Gamma without destination Quantity(1735.3,6) null
# WARNING Gamma without destination Quantity(1753.0,8) null
# WARNING Gamma without destination Quantity(1757.9,5) null
# WARNING Gamma without destination Quantity(1766.1,5) null
# WARNING Gamma without destination Quantity(1816.3,4) null
# WARNING Gamma without destination Quantity(1827.2,4) null
# WARNING Gamma without destination Quantity(1830.7,5) null
# WARNING Gamma without destination Quantity(1834.0,4) null
# WARNING Gamma without destination Quantity(1861.6,4) null
# WARNING Gamma without destination Quantity(1867.4,4) null
# WARNING Gamma without destination Quantity(1875.9,5) null
# WARNING Gamma without destination Quantity(1887.8,5) null
# WARNING Gamma without destination Quantity(1900.7,8) null
# WARNING Gamma without destination Quantity(1902.7,5) null
# WARNING Gamma without destination Quantity(1909.6,5) null
# WARNING Gamma without destination Quantity(1913.0,7) null
# WARNING Gamma without destination Quantity(1926.5,6) null
# WARNING Gamma without destination Quantity(1934.9,7) null
# WARNING Gamma without destination Quantity(1941.2,5) null
# WARNING Gamma without destination Quantity(1952.5,6) null
# WARNING Gamma without destination Quantity(1958.2,5) null
# WARNING Gamma without destination Quantity(1984.9,5) null
# WARNING Gamma without destination Quantity(2010.7,5) null
# WARNING Gamma without destination Quantity(2043.9,6) null
# WARNING Gamma without destination Quantity(2062.2,5) null
# WARNING Gamma without destination Quantity(2095.2,4) null
# WARNING Gamma without destination Quantity(2115.0,7) null
# WARNING Gamma without destination Quantity(2129.5,7) null
# WARNING Gamma without destination Quantity(2139.0,9) null
# WARNING Gamma without destination Quantity(2154.4,4) null
# WARNING Gamma without destination Quantity(2174.4,8) null
# WARNING Gamma without destination Quantity(2190.8,7) null
# WARNING Gamma without destination Quantity(2223.5,8) null
# WARNING Gamma without destination Quantity(2374.0,10) null
# WARNING level with no output 590.06
# WARNING level with no output 266.44
# WARNING level with no output 296.69
# WARNING level with no output 59.501
# WARNING level with no output 463.11
# WARNING level with no output 249.77
# WARNING level with no output 396.44
# WARNING level with no output 212.91
# WARNING level with no output 267.45
# WARNING level with no output 172.06
# WARNING level with no output 369.48
# WARNING level with no output 143.89
# WARNING level with no output 843.16
# WARNING level with no output 1481.20
# WARNING level with no output 2044.6
# WARNING level with no output 1960.25
# WARNING level with no output 217.34
# WARNING level with no output 189.42
# WARNING level with no output 724.84
# WARNING level with no output 496.28
# WARNING level with no output 2063.09
# WARNING level with no output 390.20
# WARNING level with no output 388.45
# WARNING level with no output 2066.89
# No relative intensity on Gamma 28.18
# No relative intensity on Gamma 23.49
# No relative intensity on Gamma 40.86
# No relative intensity on Gamma 27.92
# No relative intensity on Gamma 16.70
# No relative intensity on Gamma 46.86
# WARNING Energy 7.4: RI not specified
# WARNING Energy 18.9: RI not specified
# WARNING Energy 15.4: RI not specified
# WARNING record without gamma normalization specified
# WARNING Gamma without destination Quantity(161.85,15) null
# WARNING Gamma without destination Quantity(197.7,5) null
# WARNING Gamma without destination Quantity(261.2,3) null
# WARNING Gamma without destination Quantity(310.3,3) null
# WARNING Gamma without destination Quantity(381.03,14) null
# WARNING Gamma without destination Quantity(536.6,3) null
# WARNING Gamma without destination Quantity(552.1,5) null
# WARNING Gamma without destination Quantity(555.50,15) null
# WARNING Gamma without destination Quantity(566.92,22) null
# WARNING Gamma without destination Quantity(641.22,21) null
# WARNING Gamma without destination Quantity(644.9,4) null
# WARNING Gamma without destination Quantity(714.9,4) null
# WARNING Gamma without destination Quantity(722.15,23) null
# WARNING Gamma without destination Quantity(730.9,5) null
# WARNING Gamma without destination Quantity(745.6,4) null
# WARNING Gamma without destination Quantity(771.24,28) null
# WARNING Gamma without destination Quantity(781.2,3) null
# WARNING Gamma without destination Quantity(789.47,27) null
# WARNING Gamma without destination Quantity(793.02,23) null
# WARNING Gamma without destination Quantity(800.45,28) null
# WARNING Gamma without destination Quantity(805.24,24) null
# WARNING Gamma without destination Quantity(813.15,28) null
# WARNING Gamma without destination Quantity(816.5,3) null
# WARNING Gamma without destination Quantity(823.5,5) null
# WARNING Gamma without destination Quantity(842.7,3) null
# WARNING Gamma without destination Quantity(959.6,4) null
# WARNING Gamma without destination Quantity(1007.2,4) null
# WARNING Gamma without destination Quantity(1018.5,4) null
# WARNING Gamma without destination Quantity(1038.2,5) null
# WARNING Gamma without destination Quantity(1042.7,4) null
# WARNING Gamma without destination Quantity(1117.3,5) null
# WARNING Gamma without destination Quantity(1145.6,5) null
# WARNING Gamma without destination Quantity(1167.1,6) null
# WARNING Gamma without destination Quantity(1182.5,5) null
# WARNING Gamma without destination Quantity(1364.9,5) null
# WARNING Gamma without destination Quantity(1517.8,5) null
# WARNING Gamma without destination Quantity(1805.8,15) null
# WARNING level with no output 678.08
# WARNING level with no output 22.80
# WARNING level with no output 709.66
# WARNING level with no output 18.90
# WARNING level with no output 433.3
# WARNING level with no output 647.89
# WARNING level with no output 638.74
# WARNING level with no output 78.20
# WARNING level with no output 159.12
# WARNING level with no output 1180.70
# WARNING level with no output 211.07
# WARNING level with no output 367.4
# WARNING level with no output 625.5
# WARNING level with no output 167.24
# WARNING level with no output 465.8
# WARNING level with no output 7.4
# WARNING level with no output 337.52
# No relative intensity on Gamma 7.4
# No relative intensity on Gamma 18.90
# No relative intensity on Gamma 15.4
# WARNING record without gamma normalization specified
# WARNING Gamma without destination Quantity(105.20,10) null
# WARNING Gamma without destination Quantity(177.13,20) null
# WARNING Gamma without destination Quantity(204.57,20) null
# WARNING Gamma without destination Quantity(221.76,20) null
# WARNING Unbalanced level 110.79:TimeQuantity(,null) in=1.6099999999999999 out=9.89 1.4400000000000002
# WARNING Unbalanced level 43.67:TimeQuantity(,null) in=6.72 out=42.7 1.4560906515580738
# WARNING Unbalanced level 197.20:TimeQuantity(,null) in=0.14 out=0.17 0.19354838709677416
# WARNING Unbalanced level 211.08:TimeQuantity(,null) in=0.49 out=1.15 0.8048780487804877
# WARNING Unbalanced level 367.28:TimeQuantity(,null) in=0.0 out=1.12 2.0
# WARNING Energy 30.7: RI not specified
# Bad quantity 135.8+X
# Bad quantity 0+X
# Bad quantity 0+X
# Bad quantity 135.8+X
# Bad quantity 166.5+X
# Bad quantity 166.5+X
# Bad quantity 0+X
# Bad quantity 135.8+X
# Bad quantity 166.5+X
# WARNING Bad linkage 161LU IT DECAY (7.3 MS) Quantity(30.7,null)
# WARNING level with no output 166.5+X
# WARNING Unbalanced level 135.8+X:TimeQuantity(,null) in=0.0 out=0.9881 2.0
# WARNING level with no output 0+X
# No relative intensity on Gamma 30.7
# WARNING record without gamma normalization specified
# Bad quantity 135.6+X
# Bad quantity 0+X
# Bad quantity 0+X
# Bad quantity 66.7+X
# Bad quantity 135.6+X
# Bad quantity 226.8+X
# Bad quantity 275.9+X
# Bad quantity 335.2+X
# Bad quantity 444.4+X
# Bad quantity 226.8+X
# Bad quantity 0+X
# Bad quantity 66.7+X
# Bad quantity 135.6+X
# Bad quantity 226.8+X
# Bad quantity 275.9+X
# Bad quantity 335.2+X
# Bad quantity 444.4+X
# WARNING Bad linkage 161HF EC DECAY Quantity(91.2,5)
# Bad quantity 275.9+X
# Bad quantity 0+X
# Bad quantity 66.7+X
# Bad quantity 135.6+X
# Bad quantity 226.8+X
# Bad quantity 275.9+X
# Bad quantity 335.2+X
# Bad quantity 444.4+X
# WARNING Bad linkage 161HF EC DECAY Quantity(209.2,5)
# Bad quantity 275.9+X
# Bad quantity 0+X
# Bad quantity 0+X
# Bad quantity 66.7+X
# Bad quantity 135.6+X
# Bad quantity 226.8+X
# Bad quantity 275.9+X
# Bad quantity 335.2+X
# Bad quantity 444.4+X
# Bad quantity 335.2+X
# Bad quantity 0+X
# Bad quantity 66.7+X
# Bad quantity 135.6+X
# Bad quantity 226.8+X
# Bad quantity 275.9+X
# Bad quantity 335.2+X
# Bad quantity 444.4+X
# WARNING Bad linkage 161HF EC DECAY Quantity(199.6,4)
# Bad quantity 444.4+X
# Bad quantity 0+X
# Bad quantity 66.7+X
# Bad quantity 135.6+X
# Bad quantity 226.8+X
# Bad quantity 275.9+X
# Bad quantity 335.2+X
# Bad quantity 444.4+X
# WARNING Bad linkage 161HF EC DECAY Quantity(217.6,4)
# WARNING level with no output 0+X
# WARNING Unbalanced level 444.4+X:TimeQuantity(,null) in=0.0 out=0.089883 2.0
# WARNING Unbalanced level 275.9+X:TimeQuantity(,null) in=0.0 out=0.409467 2.0
# WARNING Unbalanced level 226.8+X:TimeQuantity(,null) in=0.0 out=0.049935 2.0
# WARNING Unbalanced level 335.2+X:TimeQuantity(,null) in=0.0 out=0.14980500000000002 2.0
# WARNING Unbalanced level 135.6+X:TimeQuantity(,null) in=0.0 out=0.9987 2.0
# WARNING level with no output 66.7+X
# WARNING parent nuclide is null
# WARNING Decay to multiple daughters
# Bad quantity 0+X
# WARNING parent nuclide is null
# WARNING Decay to multiple daughters
# WARNING Energy 36.0: RI not specified
# WARNING Energy 736.6: RI not specified
# WARNING Energy 741.1: RI not specified
# WARNING Gamma without destination Quantity(36.0,null) null
# WARNING Gamma without destination Quantity(736.6,null) null
# WARNING Gamma without destination Quantity(741.1,null) null
# No relative intensity on Gamma 36.0
# No relative intensity on Gamma 736.6
# No relative intensity on Gamma 741.1
# WARNING Gamma without destination Quantity(1267.5,6) null
# WARNING Gamma without destination Quantity(1287.6,5) null
# WARNING Gamma without destination Quantity(1547.4,6) null
# WARNING Gamma without destination Quantity(1556.5,6) null
# WARNING Gamma without destination Quantity(1806.1,8) null
# WARNING Gamma without destination Quantity(2167.3,6) null
# WARNING Gamma without destination Quantity(2233.0,8) null
# WARNING Unbalanced level 1210.0:TimeQuantity(,null) in=6.848E-5 out=2.6209712059999997E-4 1.17138851139234
# WARNING Gamma without destination Quantity(540,2) null
# WARNING Gamma without destination Quantity(1134,1) null
# WARNING Gamma without destination Quantity(1806,2) null
# WARNING Unbalanced level 888.18:TimeQuantity(,null) in=0.003099548 out=0.00134288089 0.7908588537924802
# WARNING Unbalanced level 1453.48:TimeQuantity(,null) in=0.0 out=0.013086566313999999 2.0
# WARNING Unbalanced level 265.61:TimeQuantity(,null) in=0.00486938838 out=0.005492014 0.12018172775565929
# WARNING level with no output 1061.00
# WARNING Unbalanced level 1061.00:TimeQuantity(,null) in=6.876E-5 out=0.0 2.0
# No relative intensity on Gamma 1400.3
# WARNING Unbalanced level 1182.79:TimeQuantity(,null) in=0.005943125349000001 out=0.0063964357127999985 0.07347268861990977
# WARNING Unbalanced level 1390.54:TimeQuantity(,null) in=0.019152 out=0.015609611367000002 0.2038103812622949
# WARNING Unbalanced level 1485.70:TimeQuantity(1.92 NS,11) in=0.14961822080000003 out=0.37761470642699996 0.8648795393950655
# WARNING Unbalanced level 1530.26:TimeQuantity(,null) in=2.394E-4 out=6.299030556E-4 0.8984278913651619
# WARNING Unbalanced level 1148.36:TimeQuantity(,null) in=0.0 out=7.358677199999999E-5 2.0
# WARNING Unbalanced level 265.66:TimeQuantity(0.132 NS,8) in=0.37921533380859995 out=0.3128958 0.19164417553479296
# WARNING Unbalanced level 1324.51:TimeQuantity(,null) in=9.99899586E-4 out=0.0011544480864 0.14347591373478613
# WARNING Unbalanced level 962.99:TimeQuantity(,null) in=0.004562875422 out=0.0037269346716000003 0.2016791074732515
# WARNING Unbalanced level 1296.95:TimeQuantity(,null) in=0.00242421228 out=0.004400028360000001 0.5790581499775483
# WARNING Unbalanced level 1575.64:TimeQuantity(,null) in=0.006118 out=0.015499482818399999 0.8679533040188036
# WARNING Unbalanced level 1210.14:TimeQuantity(,null) in=0.007836466932000002 out=0.0094381807716 0.1854409846246768
# WARNING Unbalanced level 888.36:TimeQuantity(,null) in=9.721751508E-4 out=0.001202089644 0.21148711394294423
# WARNING Unbalanced level 1061.02:TimeQuantity(,null) in=0.007136171658 out=0.0058897197576 0.19138066802971057
# WARNING Unbalanced level 105.87:TimeQuantity(67.0 M,7) in=0.0 out=1.0 2.0
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING Energy 452.0: RI not specified
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# WARNING electron capture without intensity Quantity(,null)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Beta-:  1176.0 5.29996926017829
# Beta-:  892.1300000000001 0.000579996636019511 2U
# Beta-:  514.03 94.6994507431857 1U
# Gamma:  283.5 0.00058
# Gamma:  661.657 85.1353
# Xray:  31.452 0.0038779479452758564 K-L1
# Xray:  31.817 2.0544464746672535 K-L2
# Xray:  32.194 3.7840987830075132 K-L3
# Xray:  36.304 0.3555689274899637 K-M2
# Xray:  36.378 0.6867383620253872 K-M3
# Xray:  36.645300000000006 0.010002101780727657 K-M4,5
# Xray:  37.249 0.2648869864347053 K-N2,3
# Xray:  37.348400000000005 0.0027972035398852813 K-N4,5
# Xray:  4.852 0.021539274484727998 L1-M2
# Xray:  4.926 0.03625882354068 L1-M3
# Xray:  5.797 0.0065265809393616 L1-N2
# Xray:  5.8104 0.008654943631152 L1-N3
# Xray:  4.331 0.0031580679094847996 L2-M1
# Xray:  4.8283000000000005 0.11481044145292799 L2-M4
# Xray:  5.5314 0.016763168949696 L2-N4
# Xray:  3.954 0.0039861972746856 L3-M1
# Xray:  4.451300000000001 0.011125309256458802 L3-M4
# Xray:  4.4665 0.099945988578384 L3-M5
# Xray:  4.9935 0.0007505941455167998 L3-N1
# Xray:  5.1544 0.020326867063932 L3-N4,5

# %%
e_values = beta_record['E']
i_values = beta_record['I']
plt.vlines(e_values, ymin=0, ymax=i_values, linewidth=1, color='blue', label="Calculated", alpha=0.7)
E = [513.97, 892.13, 1175.63]
I = [94.70, 5.8E-4, 5.30]
plt.vlines(E, ymin=0, ymax=I, linewidth=1, color='red', label="NuDat", alpha=0.7)
plt.xlabel('Energy')
plt.ylabel('Intensity')
plt.yscale('log')
plt.ylim(ymin = 1E-5, ymax = 100)
plt.title('Beta (Endpoint)')
plt.legend()
plt.show()

# %%
e_values = gamma_record['E']
i_values = gamma_record['I']
plt.vlines(e_values, ymin=0, ymax=i_values, linewidth=1, color='blue', label="Calculated", alpha=0.7)
E = [283.5, 661.657]
I = [5.8E-4, 85.10]
plt.vlines(E, ymin=0, ymax=I, linewidth=1, color='red', label="NuDat", alpha=0.7)
plt.xlabel('Energy')
plt.ylabel('Intensity')
plt.yscale('log')
plt.ylim(ymin = 1E-5, ymax = 100)
plt.title('Gamma')
plt.legend()
plt.show()

# %%
e_values = xray_record['E']
i_values = xray_record['I']
plt.vlines(e_values, ymin=0, ymax=i_values, linewidth=1, color='blue', label="Calculated", alpha=0.7)
E = [4.47, 31.817, 32.194, 36.304, 36.378, 37.255]
I = [0.91, 1.99, 3.64, 0.348, 0.672, 0.213]
plt.vlines(E, ymin=0, ymax=I, linewidth=1, color='red', label="NuDat", alpha=0.7)
plt.xlabel('Energy')
plt.ylabel('Intensity')
plt.yscale('log')
plt.ylim(ymin = 1E-2, ymax = 10)
plt.title('Xray')
plt.legend()
plt.show()
